# %% [markdown]
# <a href="https://colab.research.google.com/github/Rrm1234/Linear-Regression/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded = files.upload()
data = pd.read_csv("dataClean.csv")
# Out:
#      <input type="file" id="files-424881ca-961f-47f2-a694-620c3df83595" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-424881ca-961f-47f2-a694-620c3df83595">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataClean.csv to dataClean.csv

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X=DataFrame(data,columns=['production_budget_usd'])
y=DataFrame(data,columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.title('Film cost vs global revenue')
plt.scatter(X,y,alpha=0.3)
plt.xlabel('production budget ')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %%
regression=LinearRegression()
regression.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coefficient:

# %%
regression.coef_
# Out:
# array([[3.11150918]])

# %% [markdown]
# Intercept:

# %%
regression.intercept_
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(10,6))
plt.title('Film cost vs global revenue')
plt.plot(X,regression.predict(X),color='red',linewidth=4)
plt.scatter(X,y,alpha=0.3)
plt.xlabel('production budget ')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()
